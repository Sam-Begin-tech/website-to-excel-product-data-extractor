# %% [markdown]
# # Web Page Data Extraction to Excel - Demo
#
# This Python prototype automates the process of crawling a website, extracting product details, and saving them into an Excel file. It uses an LLM (via LangChain with Ollama- Gemma 2) to intelligently extract structured product data such as Product Name, MRP, and Selling Price from unstructured webpage text.
#
# 1. Start URL is defined and crawled recursively.
#
# 2. All page text is cleaned and chunked.
#
# 3. Each chunk is passed to an LLM prompt that extracts product data.
#
# 4. Valid JSONs are parsed and deduplicated.
#
# 5. Final output is saved to an Excel file.

# %%
# %pip install requests bs4 langchain_ollama pandas
# Out:
# Requirement already satisfied: requests in .\myenv\lib\site-packages (2.32.4)
# Requirement already satisfied: bs4 in .\myenv\lib\site-packages (0.0.2)
# Requirement already satisfied: langchain_ollama in .\myenv\lib\site-packages (0.3.3)
# Requirement already satisfied: pandas in .\myenv\lib\site-packages (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in .\myenv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in .\myenv\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: beautifulsoup4 in .\myenv\lib\site-packages (from bs4) (4.13.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.60 in .\myenv\lib\site-packages (from langchain_ollama) (0.3.65)
# Requirement already satisfied: ollama<1.0.0,>=0.4.8 in .\myenv\lib\site-packages (from langchain_ollama) (0.5.1)
# Requirement already satisfied: tzdata>=2022.7 in .\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in .\myenv\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.60->langchain_ollama) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in .\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.60->langchain_ollama) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in .\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.60->langchain_ollama) (24.2)
# Requirement already satisfied: pydantic>=2.7.4 in .\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.60->langchain_ollama) (2.11.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.60->langchain_ollama) (9.1.2)
# Requirement already satisfied: langsmith<0.4,>=0.3.45 in .\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.60->langchain_ollama) (0.3.45)
# Requirement already satisfied: typing-extensions>=4.7 in .\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.60->langchain_ollama) (4.14.0)
# Requirement already satisfied: httpx>=0.27 in .\myenv\lib\site-packages (from ollama<1.0.0,>=0.4.8->langchain_ollama) (0.28.1)
# Requirement already satisfied: six>=1.5 in .\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in .\myenv\lib\site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: anyio in .\myenv\lib\site-packages (from httpx>=0.27->ollama<1.0.0,>=0.4.8->langchain_ollama) (4.9.0)
# Requirement already satisfied: httpcore==1.* in .\myenv\lib\site-packages (from httpx>=0.27->ollama<1.0.0,>=0.4.8->langchain_ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama<1.0.0,>=0.4.8->langchain_ollama) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.60->langchain_ollama) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\myenv\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.60->langchain_ollama) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\myenv\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.60->langchain_ollama) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in .\myenv\lib\site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.60->langchain_ollama) (0.23.0)
# Requirement already satisfied: pydantic-core==2.33.2 in .\myenv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.60->langchain_ollama) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in .\myenv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.60->langchain_ollama) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.60->langchain_ollama) (0.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\myenv\lib\site-packages (from anyio->httpx>=0.27->ollama<1.0.0,>=0.4.8->langchain_ollama) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in .\myenv\lib\site-packages (from anyio->httpx>=0.27->ollama<1.0.0,>=0.4.8->langchain_ollama) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'd:\python\copilot\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import re
import json
import pandas as pd
import numpy as np
from langchain_ollama import OllamaLLM

# %% [markdown]
# # ---------------------------------------
# # 1. Web Crawler
# # ---------------------------------------

# %%
visited = set()

def crawl(url, domain):
    """Recursively crawl a domain to collect text from pages."""
    if url in visited or domain not in url:
        return []
    visited.add(url)
    print(f"Crawling: {url}")

    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")
        texts = [soup.get_text()]
        for link in soup.find_all("a", href=True):
            next_url = urljoin(url, link['href'])
            if domain in next_url:
                texts += crawl(next_url, domain)
        return texts
    except Exception as e:
        print(f"Error crawling {url}: {e}")
        return []

# %% [markdown]
# # ---------------------------------------
# # 2. Text Cleaning
# # ---------------------------------------

# %%
def clean_text(raw_text):
    """Clean raw HTML page text."""
    text = re.sub(r'<[^>]+>', '', raw_text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'not found 404 not found', '', text, flags=re.IGNORECASE)
    text = re.sub(r'loading\.\.\.|add to cart|shop now|my cart|login|register', '', text, flags=re.IGNORECASE)
    return text.strip()

def chunk_text(text, max_chars=2000):
    """Split large text into chunks for LLM input."""
    return [text[i:i + max_chars] for i in range(0, len(text), max_chars)]

# %% [markdown]
# # ---------------------------------------
# # 3. LLM Processing
# # ---------------------------------------

# %%
def extract_data_with_llm(chunks, model_name="gemma2:2b"):
    """Use Ollama LLM to extract structured data from text chunks."""
    llm = OllamaLLM(model=model_name, temperature=0)
    replies = []

    for chunk in chunks:
        prompt = f"""
Extract the following fields from the text: Product Name, MRP, and Selling Price.

Only respond with a **valid JSON object** in the exact format below, using actual values **from the text**:
{{
    "ProductName": "Exact product name from the text",
    "MRP": "₹[amount]",
    "sellingPrice": "₹[amount]"
}}

- If any value is missing or unclear, return null for that field.
- No explanations or extra text—just the JSON object.

Text:
\"\"\"{chunk}\"\"\"
"""
        reply = llm.invoke(prompt)
        replies.append(reply)
    return replies

# %% [markdown]
# # ---------------------------------------
# # 4. JSON Cleaning and Parsing
# # ---------------------------------------

# %%
def clean_json_string(raw_output):
    """Clean up extra formatting from LLM output."""
    return re.sub(r"```(json)?", "", raw_output).strip("` \n")

def parse_json_responses(replies):
    """Parse and filter valid JSON objects from LLM replies."""
    data = []
    for item in replies:
        cleaned = clean_json_string(item)
        try:
            parsed = json.loads(cleaned)
            if isinstance(parsed, dict):
                data.append(parsed)
        except json.JSONDecodeError as e:
            print("Error parsing JSON:", e)
            print("Problematic string:", cleaned)
    return data

# %% [markdown]
# # ---------------------------------------
# # 5. Deduplication
# # ---------------------------------------

# %%
def deduplicate_data(data):
    """Deduplicate product entries by name."""
    unique_data = {}
    for item in data:
        product_name = item.get("ProductName", "")
        if not isinstance(product_name, str) or not product_name.strip():
            continue
        product_name = product_name.strip()
        if product_name not in unique_data:
            unique_data[product_name] = item
    return list(unique_data.values())

# %% [markdown]
# # ---------------------------------------
# # 6. Save to Excel
# # ---------------------------------------

# %%
def save_to_excel(data, filename="products.xlsx"):
    """Save structured product data to Excel."""
    df = pd.DataFrame(data)
    df.replace(["null", "None", "", None], np.nan, inplace=True)
    df.dropna(subset=['ProductName'], inplace=True)
    df.to_excel(filename, index=False)
    return df

# %% [markdown]
# # ---------------------------------------
# # Main Process
# # ---------------------------------------

# %%
def main():
    start_url = "https://edenmart.in/"
    domain = urlparse(start_url).netloc

    # Step 1: Crawl website
    raw_texts = crawl(start_url, domain)

    # Step 2: Clean and chunk text
    full_cleaned_text = "\n---\n".join(clean_text(text) for text in raw_texts if text)
    chunks = chunk_text(full_cleaned_text)

    # Step 3: Extract structured data from chunks
    replies = extract_data_with_llm(chunks)

    # Step 4: Clean and parse JSON replies
    parsed_data = parse_json_responses(replies)

    # Step 5: Deduplicate by product name
    deduplicated = deduplicate_data(parsed_data)

    # Step 6: Save to Excel
    df = save_to_excel(deduplicated, filename="productsnew4.xlsx")

    print(df)

main()
# Out:
# Crawling: https://edenmart.in/
# Crawling: https://edenmart.in
# Crawling: https://edenmart.in/login
# Crawling: https://edenmart.in/cart
# Crawling: https://edenmart.in/allproductslist
# Crawling: https://edenmart.in/about
# Crawling: https://edenmart.in/contact
# Crawling: https://edenmart.in/orders
# Crawling: https://edenmart.in/index.html
# Crawling: https://edenmart.in/addresslist
# Crawling: https://edenmart.in/address
# Crawling: https://edenmart.in/Shipping_Policy
# Crawling: https://edenmart.in/Privacy_Policy
# Crawling: https://edenmart.in/return_refund
# Crawling: https://edenmart.in/terms_conditions
# Crawling: https://edenmart.in/productdetail/1
# Crawling: https://edenmart.in/productdetail/4
# Crawling: https://edenmart.in/productdetail/5
# Crawling: https://edenmart.in/productdetail/7
# Crawling: https://edenmart.in/productdetail/8
# Crawling: https://edenmart.in/productdetail/9
# Crawling: https://edenmart.in/productdetail/10
# Crawling: https://edenmart.in/productdetail/11
# Crawling: https://edenmart.in/productdetail/12
# Crawling: https://edenmart.in/productdetail/13
# Crawling: https://edenmart.in/productdetail/14
# Crawling: https://edenmart.in/productdetail/15
# Crawling: https://edenmart.in/allproductslist?page=2
# Crawling: https://edenmart.in/productdetail/16
# Crawling: https://edenmart.in/productdetail/17
# Crawling: https://edenmart.in/productdetail/18
# Crawling: https://edenmart.in/productdetail/19
# Crawling: https://edenmart.in/productdetail/20
# Crawling: https://edenmart.in/productdetail/21
# Crawling: https://edenmart.in/productdetail/22
# Crawling: https://edenmart.in/productdetail/23
# Crawling: https://edenmart.in/productdetail/24
# Crawling: https://edenmart.in/productdetail/26
# Crawling: https://edenmart.in/productdetail/27
# Crawling: https://edenmart.in/productdetail/28
# Crawling: https://edenmart.in/allproductslist?page=1
# Crawling: https://edenmart.in/allproductslist?page=3
# Crawling: https://edenmart.in/productdetail/29
# Crawling: https://edenmart.in/productdetail/30
# Crawling: https://edenmart.in/productdetail/31
# Crawling: https://edenmart.in/productdetail/32
# Crawling: https://edenmart.in/productdetail/33
# Crawling: https://edenmart.in/productdetail/34
# Crawling: https://edenmart.in/productdetail/35
# Crawling: https://edenmart.in/productdetail/36
# Crawling: https://edenmart.in/productdetail/37
# Crawling: https://edenmart.in/productdetail/38
# Crawling: https://edenmart.in/productdetail/39
# Crawling: https://edenmart.in/productdetail/40
# Crawling: https://edenmart.in/allproductslist?page=4
# Crawling: https://edenmart.in/productdetail/41
# Crawling: https://edenmart.in/productdetail/42
# Crawling: https://edenmart.in/productdetail/43
# Crawling: https://edenmart.in/productdetail/44
# Crawling: https://edenmart.in/productdetail/45
# Crawling: https://edenmart.in/productdetail/46
# Crawling: https://edenmart.in/productdetail/47
# Crawling: https://edenmart.in/productdetail/48
# Crawling: https://edenmart.in/productdetail/49
# Crawling: https://edenmart.in/productdetail/50
# Crawling: https://edenmart.in/productdetail/51
# Crawling: https://edenmart.in/productdetail/52
# Crawling: https://edenmart.in/allproductslist?page=5
# Crawling: https://edenmart.in/productdetail/53
# Crawling: https://edenmart.in/productdetail/54
# Crawling: https://edenmart.in/productdetail/55
# Crawling: https://edenmart.in/productdetail/56
# Crawling: https://edenmart.in/productdetail/57
# Crawling: https://edenmart.in/productdetail/58
# Crawling: https://edenmart.in/productdetail/59
# Crawling: https://edenmart.in/productdetail/60
# Crawling: https://edenmart.in/productdetail/61
# Crawling: https://edenmart.in/productdetail/62
# Crawling: https://edenmart.in/productdetail/63
# Crawling: https://edenmart.in/productdetail/64
# Crawling: https://edenmart.in/allproductslist?page=6
# Crawling: https://edenmart.in/productdetail/65
# Crawling: https://edenmart.in/productdetail/66
# Crawling: https://edenmart.in/productdetail/67
# Crawling: https://edenmart.in/productdetail/68
# Crawling: https://edenmart.in/productdetail/69
# Crawling: https://edenmart.in/productdetail/70
# Crawling: https://edenmart.in/productdetail/71
# Crawling: https://edenmart.in/productdetail/72
# Crawling: https://edenmart.in/productdetail/73
# Crawling: https://edenmart.in/productdetail/74
# Crawling: https://edenmart.in/productdetail/75
# Crawling: https://edenmart.in/productdetail/76
# Crawling: https://edenmart.in/allproductslist?page=7
# Crawling: https://edenmart.in/productdetail/77
# Crawling: https://edenmart.in/productdetail/78
# Crawling: https://edenmart.in/productdetail/79
# Crawling: https://edenmart.in/productdetail/81
# Crawling: https://edenmart.in/productdetail/82
# Crawling: https://edenmart.in/productdetail/83
# Crawling: https://edenmart.in/productdetail/84
# Crawling: https://edenmart.in/productdetail/85
# Crawling: https://edenmart.in/productdetail/86
# Crawling: https://edenmart.in/productdetail/87
# Crawling: https://edenmart.in/productdetail/88
# Crawling: https://edenmart.in/productdetail/89
# Crawling: https://edenmart.in/allproductslist?page=8
# Crawling: https://edenmart.in/productdetail/90
# Crawling: https://edenmart.in/productdetail/91
# Crawling: https://edenmart.in/productdetail/92
# Crawling: https://edenmart.in/productdetail/93
# Crawling: https://edenmart.in/productdetail/94
# Crawling: https://edenmart.in/productdetail/95
# Crawling: https://edenmart.in/productdetail/96
# Crawling: https://edenmart.in/productdetail/97
# Crawling: https://edenmart.in/productdetail/98
# Crawling: https://edenmart.in/productdetail/99
# Crawling: https://edenmart.in/productdetail/100
# Crawling: https://edenmart.in/productdetail/101
# Crawling: https://edenmart.in/allproductslist?page=9
# Crawling: https://edenmart.in/productdetail/102
# Crawling: https://edenmart.in/productdetail/103
# Crawling: https://edenmart.in/productdetail/104
# Crawling: https://edenmart.in/productdetail/105
# Crawling: https://edenmart.in/productdetail/106
# Crawling: https://edenmart.in/productdetail/107
# Crawling: https://edenmart.in/productdetail/108
# Crawling: https://edenmart.in/productdetail/109
# Crawling: https://edenmart.in/productdetail/110
# Crawling: https://edenmart.in/productdetail/111
# Crawling: https://edenmart.in/productdetail/112
# Crawling: https://edenmart.in/productdetail/113
# Crawling: https://edenmart.in/allproductslist?page=10
# Crawling: https://edenmart.in/productdetail/114
# Crawling: https://edenmart.in/productdetail/115
# Crawling: https://edenmart.in/productdetail/116
# Crawling: https://edenmart.in/productdetail/117
# Crawling: https://edenmart.in/productdetail/118
# Crawling: https://edenmart.in/productdetail/119
# Crawling: https://edenmart.in/productdetail/120
# Crawling: https://edenmart.in/productdetail/121
# Crawling: https://edenmart.in/productdetail/122
# Crawling: https://edenmart.in/productdetail/123
# Crawling: https://edenmart.in/productdetail/124
# Crawling: https://edenmart.in/productdetail/125
# Crawling: https://edenmart.in/allproductslist?page=11
# Crawling: https://edenmart.in/productdetail/126
# Crawling: https://edenmart.in/productdetail/127
# Crawling: https://edenmart.in/productdetail/128
# Crawling: https://edenmart.in/productdetail/129
# Crawling: https://edenmart.in/productdetail/130
# Crawling: https://edenmart.in/productdetail/131
# Crawling: https://edenmart.in/productdetail/132
# Crawling: https://edenmart.in/productdetail/133
# Crawling: https://edenmart.in/productdetail/134
# Crawling: https://edenmart.in/productdetail/135
# Crawling: https://edenmart.in/productdetail/137
# Crawling: https://edenmart.in/productdetail/138
# Crawling: https://edenmart.in/allproductslist?page=12
# Crawling: https://edenmart.in/productdetail/139
# Crawling: https://edenmart.in/productdetail/140
# Crawling: https://edenmart.in/productdetail/141
# Crawling: https://edenmart.in/productdetail/142
# Crawling: https://edenmart.in/productdetail/143
# Crawling: https://edenmart.in/productdetail/144
# Crawling: https://edenmart.in/productdetail/145
# Crawling: https://edenmart.in/productdetail/146
# Crawling: https://edenmart.in/productdetail/147
# Crawling: https://edenmart.in/productdetail/148
# Crawling: https://edenmart.in/productdetail/149
# Crawling: https://edenmart.in/productdetail/150
# Crawling: https://edenmart.in/allproductslist?page=13
# Crawling: https://edenmart.in/productdetail/151
# Crawling: https://edenmart.in/productdetail/152
# Crawling: https://edenmart.in/productdetail/153
# Crawling: https://edenmart.in/productdetail/154
# Crawling: https://edenmart.in/productdetail/155
# Crawling: https://edenmart.in/productdetail/156
# Crawling: https://edenmart.in/productdetail/157
# Crawling: https://edenmart.in/productdetail/158
# Crawling: https://edenmart.in/productdetail/159
# Crawling: https://edenmart.in/productdetail/160
# Crawling: https://edenmart.in/productdetail/161
# Crawling: https://edenmart.in/productdetail/162
# Crawling: https://edenmart.in/allproductslist?page=14
# Crawling: https://edenmart.in/productdetail/163
# Crawling: https://edenmart.in/productdetail/164
# Crawling: https://edenmart.in/productdetail/165
# Crawling: https://edenmart.in/productdetail/166
# Crawling: https://edenmart.in/productdetail/167
# Crawling: https://edenmart.in/productdetail/168
# Crawling: https://edenmart.in/productdetail/169
# Crawling: https://edenmart.in/productdetail/170
# Crawling: https://edenmart.in/productdetail/171
# Crawling: https://edenmart.in/productdetail/172
# Crawling: https://edenmart.in/productdetail/173
# Crawling: https://edenmart.in/productdetail/174
# Crawling: https://edenmart.in/allproductslist?page=15
# Crawling: https://edenmart.in/productdetail/175
# Crawling: https://edenmart.in/productdetail/176
# Crawling: https://edenmart.in/productdetail/177
# Crawling: https://edenmart.in/productdetail/178
# Crawling: https://edenmart.in/productdetail/179
# Crawling: https://edenmart.in/productdetail/180
# Crawling: https://edenmart.in/productdetail/181
# Crawling: https://edenmart.in/productdetail/182
# Crawling: https://edenmart.in/productdetail/183
# Crawling: https://edenmart.in/productdetail/184
# Crawling: https://edenmart.in/productdetail/185
# Crawling: https://edenmart.in/productdetail/186
# Crawling: https://edenmart.in/allproductslist?page=16
# Crawling: https://edenmart.in/productdetail/187
# Crawling: https://edenmart.in/productdetail/188
# Crawling: https://edenmart.in/productdetail/189
# Crawling: https://edenmart.in/productdetail/190
# Crawling: https://edenmart.in/productdetail/191
# Crawling: https://edenmart.in/productdetail/193
# Crawling: https://edenmart.in/productdetail/194
# Crawling: https://edenmart.in/productdetail/195
# Crawling: https://edenmart.in/productdetail/196
# Crawling: https://edenmart.in/productdetail/197
# Crawling: https://edenmart.in/productdetail/198
# Crawling: https://edenmart.in/productdetail/199
# Crawling: https://edenmart.in/allproductslist?page=17
# Crawling: https://edenmart.in/productdetail/200
# Crawling: https://edenmart.in/productdetail/201
# Crawling: https://edenmart.in/productdetail/202
# Crawling: https://edenmart.in/productdetail/203
# Crawling: https://edenmart.in/productdetail/204
# Crawling: https://edenmart.in/productdetail/205
# Crawling: https://edenmart.in/productdetail/206
# Crawling: https://edenmart.in/productdetail/207
# Crawling: https://edenmart.in/productdetail/208
# Crawling: https://edenmart.in/productdetail/209
# Crawling: https://edenmart.in/productdetail/210
# Crawling: https://edenmart.in/productdetail/211
# Crawling: https://edenmart.in/allproductslist?page=18
# Crawling: https://edenmart.in/productdetail/212
# Crawling: https://edenmart.in/productdetail/213
# Crawling: https://edenmart.in/productdetail/214
# Crawling: https://edenmart.in/productdetail/215
# Crawling: https://edenmart.in/productdetail/216
# Crawling: https://edenmart.in/auth/google
# Crawling: https://edenmart.in/signin/v2/usernamerecovery?app_domain=https://edenmart.in&client_id=250584875040-9uiortbpod1qh2ompbh8dj5q2bso2cqv.apps.googleusercontent.com&continue=https://accounts.google.com/signin/oauth/legacy/consent?authuser%3Dunknown%26part%3DAJi8hAPY8AGA2R_fVB_bvpWEgI-udykInrvwYRT9eVbEDlsezk-_bHXzGJdjEtyEPZtoNv8DtjRiQSvKHc07OZxdR_oYEw8oeWMhyzrjos3kOuShlpZrfcj9sTelxs3_8Nb5DCWlwLiZF3QSdKDaUHMpyR1Eq1ec99kNJBjJ0uVwV9hOFsajnMey4wqyX9j89HIvWyHjOb-erHSWuM9onYEHm9rzlypVXDX3sNoU2mpThhjMsc0eoBEN6kf82BRR4lLEhS8mAW0Jeuu96qhwAaTLuKqCoLuBdjb9qpQa4VnA36N5-K8qaMI9iCnbKKKMc5JFzw72potYrVtxlU6XL_UnAoStQxdJiKf2t2nyzTP5NlVRWpAQC_rCh9zLpJMxEWN-ezZxHOZ4Gi5AH8LdVIltS3gJ7ci6ikvkMTyQB9Naccu1P8oFN1PbK0HOcEk26cQGzfqIiKcKCNwRDRDsteRhdjY04Y3RLA%26flowName%3DGeneralOAuthFlow%26as%3DS-63692445%253A1749696507999912%26client_id%3D250584875040-9uiortbpod1qh2ompbh8dj5q2bso2cqv.apps.googleusercontent.com%23&dsh=S-63692445:1749696507999912&flowName=GeneralOAuthLite&o2v=1&opparams=%253F&rart=ANgoxccVK0E17JDZUy8O_Uo7I_yjIV3Epjwqtj2XeD9SnR1kfwgsKaW-o3AkbJhp1VGXVor3F6Tz8Yl4DLxDWt9PGYt8IqiNmXZcebhyA446WAcV-gh4x6w&redirect_uri=https://edenmart.in/auth/google/callback&response_type=code&scope=openid+profile+email&service=lso&state=VXYpmRzjfZeqAOwrqZozm9QfNupPkyhAnR8a6bbr
# Crawling: https://edenmart.in/lifecycle/flows/signup?app_domain=https://edenmart.in&client_id=250584875040-9uiortbpod1qh2ompbh8dj5q2bso2cqv.apps.googleusercontent.com&continue=https://accounts.google.com/signin/oauth/legacy/consent?authuser%3Dunknown%26part%3DAJi8hAPY8AGA2R_fVB_bvpWEgI-udykInrvwYRT9eVbEDlsezk-_bHXzGJdjEtyEPZtoNv8DtjRiQSvKHc07OZxdR_oYEw8oeWMhyzrjos3kOuShlpZrfcj9sTelxs3_8Nb5DCWlwLiZF3QSdKDaUHMpyR1Eq1ec99kNJBjJ0uVwV9hOFsajnMey4wqyX9j89HIvWyHjOb-erHSWuM9onYEHm9rzlypVXDX3sNoU2mpThhjMsc0eoBEN6kf82BRR4lLEhS8mAW0Jeuu96qhwAaTLuKqCoLuBdjb9qpQa4VnA36N5-K8qaMI9iCnbKKKMc5JFzw72potYrVtxlU6XL_UnAoStQxdJiKf2t2nyzTP5NlVRWpAQC_rCh9zLpJMxEWN-ezZxHOZ4Gi5AH8LdVIltS3gJ7ci6ikvkMTyQB9Naccu1P8oFN1PbK0HOcEk26cQGzfqIiKcKCNwRDRDsteRhdjY04Y3RLA%26flowName%3DGeneralOAuthFlow%26as%3DS-63692445%253A1749696507999912%26client_id%3D250584875040-9uiortbpod1qh2ompbh8dj5q2bso2cqv.apps.googleusercontent.com%23&dsh=S-63692445:1749696507999912&flowEntry=SignUp&flowName=GlifWebSignIn&o2v=1&opparams=%253F&rart=ANgoxccVK0E17JDZUy8O_Uo7I_yjIV3Epjwqtj2XeD9SnR1kfwgsKaW-o3AkbJhp1VGXVor3F6Tz8Yl4DLxDWt9PGYt8IqiNmXZcebhyA446WAcV-gh4x6w&redirect_uri=https://edenmart.in/auth/google/callback&response_type=code&scope=openid+profile+email&service=lso&signInUrl=https://accounts.google.com/signin/oauth?app_domain%3Dhttps://edenmart.in%26client_id%3D250584875040-9uiortbpod1qh2ompbh8dj5q2bso2cqv.apps.googleusercontent.com%26continue%3Dhttps://accounts.google.com/signin/oauth/legacy/consent?authuser%253Dunknown%2526part%253DAJi8hAPY8AGA2R_fVB_bvpWEgI-udykInrvwYRT9eVbEDlsezk-_bHXzGJdjEtyEPZtoNv8DtjRiQSvKHc07OZxdR_oYEw8oeWMhyzrjos3kOuShlpZrfcj9sTelxs3_8Nb5DCWlwLiZF3QSdKDaUHMpyR1Eq1ec99kNJBjJ0uVwV9hOFsajnMey4wqyX9j89HIvWyHjOb-erHSWuM9onYEHm9rzlypVXDX3sNoU2mpThhjMsc0eoBEN6kf82BRR4lLEhS8mAW0Jeuu96qhwAaTLuKqCoLuBdjb9qpQa4VnA36N5-K8qaMI9iCnbKKKMc5JFzw72potYrVtxlU6XL_UnAoStQxdJiKf2t2nyzTP5NlVRWpAQC_rCh9zLpJMxEWN-ezZxHOZ4Gi5AH8LdVIltS3gJ7ci6ikvkMTyQB9Naccu1P8oFN1PbK0HOcEk26cQGzfqIiKcKCNwRDRDsteRhdjY04Y3RLA%2526flowName%253DGeneralOAuthFlow%2526as%253DS-63692445%25253A1749696507999912%2526client_id%253D250584875040-9uiortbpod1qh2ompbh8dj5q2bso2cqv.apps.googleusercontent.com%2523%26dsh%3DS-63692445:1749696507999912%26flowName%3DGeneralOAuthLite%26o2v%3D1%26opparams%3D%25253F%26rart%3DANgoxccVK0E17JDZUy8O_Uo7I_yjIV3Epjwqtj2XeD9SnR1kfwgsKaW-o3AkbJhp1VGXVor3F6Tz8Yl4DLxDWt9PGYt8IqiNmXZcebhyA446WAcV-gh4x6w%26redirect_uri%3Dhttps://edenmart.in/auth/google/callback%26response_type%3Dcode%26scope%3Dopenid%2Bprofile%2Bemail%26service%3Dlso%26state%3DVXYpmRzjfZeqAOwrqZozm9QfNupPkyhAnR8a6bbr&state=VXYpmRzjfZeqAOwrqZozm9QfNupPkyhAnR8a6bbr
# Crawling: https://edenmart.in/auth/facebook
# Crawling: https://edenmart.in/r.php?locale=ta_IN
# Crawling: https://www.facebook.com/recover/initiate/?ars=facebook_login&cancel_lara_pswd=0&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://www.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://www.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ta_IN&display=page
# Crawling: https://te-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=te_IN&display=page
# Crawling: https://ta-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ta_IN&display=page
# Crawling: https://kn-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=kn_IN&display=page
# Crawling: https://ur-pk.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ur_PK&display=page
# Crawling: https://hi-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=hi_IN&display=page
# Crawling: https://ml-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ml_IN&display=page
# Crawling: https://si-lk.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=si_LK&display=page
# Crawling: https://pa-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=pa_IN&display=page
# Crawling: https://bn-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=bn_IN&display=page
# Crawling: https://gu-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=gu_IN&display=page
# Crawling: https://te-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://ta-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://kn-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://ur-pk.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://hi-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://ml-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://si-lk.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://si-lk.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=si_LK&display=page&entry_point=login
# Crawling: https://ta-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ta_IN&display=page&entry_point=login
# Crawling: https://te-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=te_IN&display=page&entry_point=login
# Crawling: https://kn-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=kn_IN&display=page&entry_point=login
# Crawling: https://ur-pk.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ur_PK&display=page&entry_point=login
# Crawling: https://hi-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=hi_IN&display=page&entry_point=login
# Crawling: https://ml-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ml_IN&display=page&entry_point=login
# Crawling: https://pa-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=pa_IN&display=page&entry_point=login
# Crawling: https://bn-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=bn_IN&display=page&entry_point=login
# Crawling: https://gu-in.facebook.com/r.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=gu_IN&display=page&entry_point=login
# Crawling: https://pa-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://bn-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://gu-in.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified
# Crawling: https://www.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://te-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://ta-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://kn-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://ur-pk.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://hi-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://ml-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://si-lk.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://pa-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://bn-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://gu-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&from_login_screen=0
# Crawling: https://edenmart.in/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ta_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT1hZEHFywNr0oCscxjzBdOHXgNiu64FX5nCeAqcS0eUsrGPR2msmD3gp1iTP-Wv3KRFhVmeeV4u2loBbwQwTj0eOz6RISNU4koOKkwabkitz2qu-5oOssylxZM7KEJLEhWJZuM-pJSulXkV77-M0IpYszCMnFPp
# Crawling: https://www.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=ta_IN&pl_dbl=0
# Crawling: https://www.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ta_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT1Z2bHWA8Em51fWnHwCwRRTAPv6dNEorxojvxuZfJi53AKQyvPN5gHiKgODxzKE737YTbWjQzgvi-B8tR5AaXMyG4SAGsYKKvHRXnSePI7ZNEkWRN59AGxTEikqxIoqxcBer2xdZ4rTka15VlwbLt4z56ihHE0L
# Crawling: https://te-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=te_IN&pl_dbl=0
# Crawling: https://te-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=te_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT0AFpgHTnr2n4SJhpGBWh8I17ga4QQk4URXCKKop-K1kEpL87LW6ciWXQBQ8Fh6rnePWo9UWhDEVqe4NKdVS94-VpoG1e4yOnQnxRVYjIDcnfm1t3w3JtCYAhW3RA0JtsRO_TEOii4r31Wi6MWZqeGX6i6Tf4Bc
# Crawling: https://ta-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=ta_IN&pl_dbl=0
# Crawling: https://ta-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ta_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT2KRnqeZxJo9Je_wBtObYOiU3MmX-DH6kHkdL40e-sdCompe8R-yipI82IO3ALdVN_WNysyvNC1l2vTOqTAd_pGsAJMb0PlNwPSX909J49Tn2lDeCaDAKM10QoL1QUKHbFaKj769n9Bk1mwIrNufEchfY4lIdzp
# Crawling: https://kn-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=kn_IN&pl_dbl=0
# Crawling: https://kn-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=kn_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT1wnHZFZLpT06lkaH39usT46qAE9C9xFPatpebJsLOkM5f7hG0ufP2IBLTdHYP7sgMDbBOQg5gQKISD-xKdmD8ZEkRpOVXHUX7HPiZSb8nf-ysrYjFMqPw94G-w50Fiw4Ds7DAa-HdlSGdHt8Gpg0yvqK6p8k3q
# Crawling: https://ur-pk.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=ur_PK&pl_dbl=0
# Crawling: https://ur-pk.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ur_PK&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT0RtbBWXpMGuuRVa8mfqVflIKV_1Qez5hrFFqI5MWEMJENA2jskm4TEtAnkq5CvYOJa8Aro3aAXXh1q0u-NnxSB6tAab1x-veTNBjjLtSguEy6YnChVXetQRDKQs4-qLOPfr16O6JqmW40FwVeUI1ZXKUngEUPR
# Crawling: https://hi-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=hi_IN&pl_dbl=0
# Crawling: https://hi-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=hi_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT3B07FCwYHlVlX7ryctaXHZoSMelHNAkZaU03TC31Qws1eu3iQXnZSVwHOuoLHOFzw4ULMDxw5gs2V5RThOFGwgwMAq2JydKqZ1H9pPCuWIKkISprnVT-HHYAy4-sUKZ5SozTG85TsjIhAipfNf4pyfRp42T5ez
# Crawling: https://ml-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=ml_IN&pl_dbl=0
# Crawling: https://ml-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=ml_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT2eLEsfQEDENtV69UnJ-8wJqOeKsLxmaWyEWeFw0A6slR8GFEAKTsOhvF6opo0WISeC9YHGu22hmT6q3cv_AN9tfkOJCTM5sxRN35R71xwrqtIhi-NRNrh5migB2wiguZGyW8fTBgzCjpYipSp7sit9817UazBa
# Crawling: https://si-lk.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=si_LK&pl_dbl=0
# Crawling: https://si-lk.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=si_LK&display=page&entry_point=login
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT3ckcWSgMxHZ2XQKcncPszpiJDR5Uk-FCh2RSziVA5hrQvSjVuJb4-G85Pg8pd_iwCP72l_ErxGbsn9-K5qZT95sHEiFl7Rs460LdOxRcD-fdexVlePXJxV83iaNip4yoP0li1qDdw3Y1NjIl_ZcRTklXF7YrIW
# Crawling: https://pa-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=pa_IN&pl_dbl=0
# Crawling: https://pa-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=pa_IN&display=page&entry_point=login
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT192dxPzIt_gRX1TRgZLIRU15jLhXDr4wtK3MxaJ7Y1U8Xq-ugJtqcOA_b3adVdRHErlco1MBG-Qe0yESWduASeu8jl2TNTvi7Il-fNGR16AzdQAFzolovjPknSeYbyn8qfofuIXnv6sy4TYP76ht4-mgPOoODN
# Crawling: https://bn-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=bn_IN&pl_dbl=0
# Crawling: https://bn-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=bn_IN&display=page
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT18jUjzIB9Bxwd5jOoP-5Cd6gr1PYtF931qa8y_K6orEptNz5c9oa-OV46e49J-ey8RWj9yXLUGV8wgkwjTKPwcJ2M0ghNuNwx4voLnZunIz0UFIltuNDIyqHR_ydDwXVsoc7XsGa6WI02R-Bcv_bV_MCFg8eCL
# Crawling: https://gu-in.facebook.com/login.php?skip_api_login=1&api_key=1032990335557053&kid_directed_site=0&app_id=1032990335557053&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&display=page&locale=gu_IN&pl_dbl=0
# Crawling: https://gu-in.facebook.com/r.php?api_key=1032990335557053&app_id=1032990335557053&cancel_url=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv3.3%2Fdialog%2Foauth%3Fclient_id%3D1032990335557053%26redirect_uri%3Dhttps%253A%252F%252Fedenmart.in%252Fauth%252Ffacebook%252Fcallback%26scope%3Demail%26response_type%3Dcode%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D3f78d432-e957-4899-8540-f1a46c04cdfc%26tp%3Dunspecified&locale=gu_IN&display=page&entry_point=login
# Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fedenmart.in%2Fauth%2Ffacebook%2Fcallback%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3DSRo9M80JlSB762gg7wFAaIZS0zCJYd9mbtAsguLl%23_%3D_&h=AT04fG-X5cAxelG-wu-cuWf0lx3zbYtcN5l5n7zQeZLgR5e5_9-Wd2Mbwz9D_MEHM06XwV0JtC3O7FBgn_lVIeURp8UZCesVLgKHBYxo-8CE3ClMc_7uUVZN0AGiPk6ifg0mxyL4RpRyA99nv1kkSSDLhS2F72dK
# Crawling: https://edenmart.in/reg/
# Crawling: https://edenmart.in/login/
# Crawling: https://edenmart.in/register
# Crawling: https://edenmart.in/lite/
# Crawling: https://edenmart.in/votinginformationcenter/?entry_point=c2l0ZQ%3D%3D
# Crawling: https://edenmart.in/privacy/policy/?entry_point=facebook_page_footer
# Crawling: https://edenmart.in/privacy/center/?entry_point=facebook_page_footer
# Crawling: https://edenmart.in/ad_campaign/landing.php?placement=pflo&campaign_id=402047449186&nav_source=unknown&extra_1=auto
# Crawling: https://edenmart.in/pages/create/?ref_type=site_footer
# Crawling: https://edenmart.in/careers/?ref=pf
# Crawling: https://edenmart.in/policies/cookies/
# Crawling: https://edenmart.in/policies?ref=pf
# Crawling: https://edenmart.in/help/?ref=pf
# Crawling: https://edenmart.in/settings
# Crawling: https://edenmart.in/allactivity?privacy_source=activity_log_top_menu
# Crawling: https://edenmart.in?page=2
# Crawling: https://edenmart.in?page=1
# Crawling: https://edenmart.in?page=3
# Crawling: https://edenmart.in?page=4
# Crawling: https://edenmart.in?page=5
# Crawling: https://edenmart.in?page=6
# Crawling: https://edenmart.in?page=7
# Crawling: https://edenmart.in?page=8
# Crawling: https://edenmart.in?page=9
# Crawling: https://edenmart.in?page=10
# Crawling: https://edenmart.in?page=11
# Crawling: https://edenmart.in?page=12
# Crawling: https://edenmart.in?page=13
# Crawling: https://edenmart.in?page=14
# Crawling: https://edenmart.in?page=15
# Crawling: https://edenmart.in?page=16
# Crawling: https://edenmart.in?page=17
# Crawling: https://edenmart.in?page=18
#                      ProductName   MRP sellingPrice
# 0                          Apple  ₹284         ₹254
# 2    9789783678 Eden supermarket   NaN          NaN
# 3               Coriander powder   ₹48          ₹45
# 4                    Country Egg    ₹8           ₹6
# 5                      White Egg    ₹6           ₹5
# ..                           ...   ...          ...
# 148                        Detto   NaN          NaN
# 149          Home lite match box  ₹137         ₹131
# 150                      Cinthol   ₹73          ₹73
# 151    Standard Horlicks Pet jar  ₹297          ₹58
# 152             Horlicks Caramel  ₹348         ₹340
#
# [152 rows x 3 columns]
